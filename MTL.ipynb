# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_tasks(p=0.5, d=100, c=1, n=300, alphas=[], betas=[]):
    '''
    d: dimensionality
    c: scaling factor
    p: correlation
    n: number of data points
    '''
    assert d >= 2, "at least 2 dimension"    
    u1, u2 = np.zeros(d), np.zeros(d)
    u1[0] = 1
    u2[1] = 1
    w1 = c * u1
    w2 = c * (p * u1 + np.sqrt(1-p**2) * u2)
    
    X = []
    Y1 = []
    Y2 = []
    for _ in range(n):
        x = np.random.normal(0, 1, d)
        y1 = w1.dot(x) + np.random.normal(0,0.01)
        y2 = w2.dot(x) + np.random.normal(0,0.01)
        for a, b in zip(alphas, betas):
            y1 += np.sin(a * w1.dot(x) + b)
            y2 += np.sin(a * w2.dot(x) + b)
            
        X.append(x)
        Y1.append(y1)
        Y2.append(y2)
    return np.vstack(X), np.array(Y1), np.array(Y2)

X, Y1, Y2 = generate_tasks(p=0,alphas=[1,2],betas=[3,4])

plt.scatter(Y1, Y2)
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.show()

# %%
corr = []
pspace = np.linspace(0,1,11)
for p in pspace:
    X, Y1, Y2 = generate_tasks(p=p, n=10000, 
                               alphas=[1,2],
                               betas=[3,4])
    corr.append(np.corrcoef(Y1, Y2)[0,1])
    
plt.plot(pspace, corr)
plt.ylabel('correlation', fontsize=15)
plt.xlabel('cos(w1, w2)', fontsize=15)
plt.grid()
plt.show()

# %%
print('number of parameters comparison')
n_neuron = 50
print('shared bottom net:', 100 * 113 + 113 * 8 + 113 * 8 + 8 + 8)
print('deep shared bottom net:', 100 * n_neuron + n_neuron*n_neuron*3 + n_neuron*8*2 + 8*2)
print('deep independent net:', (100 * 32 + 32*32*3 + 32*8 + 8)*2)
print('MMOE:', 100 * 16 * 8 + 16 * 8 * 2 + 8 + 8 + 100 * 8 * 2)
# Out:
# number of parameters comparison
# shared bottom net: 13124
# deep shared bottom net: 13316
# deep independent net: 13072
# MMOE: 14672

# %%
import torch
import torch.nn as nn

class SharedBottom(nn.Module):

    def __init__(self, l=4):
        '''
        l: number of layers
        '''
        super(SharedBottom, self).__init__()
        self.l = l
        if l == 1:
            a = int(np.round((14672 - 16) / 116))
        else:
            a = int(np.round((-116 + np.sqrt(116**2 + 4*(l-1)*(14672-16))) / (2 * (l-1))))

        print('per layer neuron: {}'.format(a))
        base = [nn.Linear(100, a), nn.ReLU(inplace=True)]
        for _ in range(l-1):
            base.extend([nn.Linear(a, a), nn.ReLU(inplace=True)])
        self.bottom = nn.Sequential(*base)    

        self.top1 = nn.Sequential(
            nn.Linear(a, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, 1)
        )
        self.top2 = nn.Sequential(
            nn.Linear(a, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, 1)
        )
        
    def forward(self, x):
        shared = self.bottom(x)
        return self.top1(shared), self.top2(shared)
    
    def name(self):
        return 'SharedBottom(l={})'.format(self.l)

class Independent(nn.Module):

    def __init__(self, l=4):
        '''
        l: number of layers
        '''
        super(Independent, self).__init__()
        self.l = l
        if l == 1:
            a = int(np.round((14672/2-8) / 108))
        else:
            a = int(np.round((-108 + np.sqrt(108**2 + 4*(l-1)*(14672/2-8))) / (2 * (l-1))))

        print('per layer neuron: {}'.format(a))
        base1 = [nn.Linear(100, a), nn.ReLU(inplace=True)]
        base2 = [nn.Linear(100, a), nn.ReLU(inplace=True)]
        for _ in range(l-1):
            base1.extend([nn.Linear(a, a), nn.ReLU(inplace=True)])
            base2.extend([nn.Linear(a, a), nn.ReLU(inplace=True)])
        base1.extend([
            nn.Linear(a, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, 1)
        ])
        base2.extend([
            nn.Linear(a, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, 1)            
        ])
        self.top1 = nn.Sequential(*base1)
        self.top2 = nn.Sequential(*base2)

    def name(self):
        return 'Independent(l={})'.format(self.l)
        
    def forward(self, x):
        return self.top1(x), self.top2(x)

class MMOE(nn.Module):

    def __init__(self):
        super(MMOE, self).__init__()

        n_experts = 8
        self.experts = nn.ModuleList()
        for _ in range(n_experts):
            self.experts.append(
                nn.Sequential(
                    nn.Linear(100, 16),
                    nn.ReLU(inplace=True)
                )
            )

        self.gates = nn.ModuleList()
        for _ in range(2): # 2 tasks
            self.gates.append(
                 nn.Sequential(
                    nn.Linear(100, n_experts),
                    nn.Softmax(dim=1)
                )            
            )
        
        
        self.top1 = nn.Sequential(
            nn.Linear(16, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, 1)
        )
        self.top2 = nn.Sequential(
            nn.Linear(16, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, 1)
        )
        
    def use_gate(self, outputs, gate_outputs):
        '''
        gate_outputs: (n, n_experts)
        '''
        res = 0
        for i in range(len(self.experts)):
            res += gate_outputs[:, i:(i+1)] * outputs[i]
        return res
        
    def forward(self, x):
        outputs = [self.experts[i](x) for i in range(len(self.experts))]
        gate_outputs = [self.gates[i](x) for i in range(2)]
        task1x = self.use_gate(outputs, gate_outputs[0])
        task2x = self.use_gate(outputs, gate_outputs[1])
        return self.top1(task1x), self.top2(task2x)
    
    def name(self):
        return "MMOE"
    
net = SharedBottom(1)
A, B = net(torch.from_numpy(X).float())
A.shape, B.shape
# Out:
# per layer neuron: 126
# (torch.Size([300, 1]), torch.Size([300, 1]))

# %%
from torch.utils.data import DataLoader  
from torch.utils.data import Dataset

class CosDataset(Dataset):
    
    def __init__(self, p=0.5, d=100, c=1, n=300, alphas=[], betas=[]):
        '''
        d: dimensionality
        c: scaling factor
        p: correlation
        n: number of data points
        '''
        self.X, self.Y1, self.Y2 = generate_tasks(p=p,d=d,c=c,n=n,
                                                  alphas=alphas,betas=betas)
        self.X = torch.from_numpy(self.X).float()
        
    def __len__(self):
        return len(self.Y1)
    
    def __getitem__(self, idx):
        return self.X[idx], (self.Y1[idx], self.Y2[idx])
    
    
def MTL_loss():
    
    def c(yhat, y):
        # regression loss on 2 tasks
        y1, y2 = y
        yhat1, yhat2 = yhat
        c_ = nn.MSELoss()
        return c_(yhat1.view(-1), y1.float().view(-1)) + c_(yhat2.view(-1), y2.float().view(-1))
        
    return c

train_data = DataLoader(CosDataset(p=0.8, n=10000), batch_size=1000)
val_data = DataLoader(CosDataset(p=0.8, n=10000), batch_size=1000)

# %% [markdown]
# # complete pipeline

# %%
from torch.utils.data import DataLoader
cos_sim = 0
n = 10000
alphas = [1, 2]
betas = [3, 4]
train_data = DataLoader(CosDataset(p=cos_sim, n=n, alphas=alphas, betas=betas), batch_size=min(1000, n))
val_data = DataLoader(CosDataset(p=cos_sim, n=n, alphas=alphas, betas=betas), batch_size=min(1000, n))

# %%
from lib.train import TrainFeedForward
nets = [Independent(1), Independent(2), SharedBottom(1), SharedBottom(2), MMOE()]
trainers = []
for net in nets:
    net_name = net.name()
    print(net_name)
    t = TrainFeedForward(net, train_data, val_data=val_data, criterion=MTL_loss(), n_iters=1000,
                         save_filename='models/{}.pth.tar'.format(net_name), n_save=30)
    trainers.append(t)
    t.train()
# Out:
# per layer neuron: 68
# per layer neuron: 47
# per layer neuron: 126
# per layer neuron: 76
# Independent(l=1)
#           #iter|       progress|     total_time|     batch_time|      data_time|       avg_loss
# ==> evaluating validation loss
# ==> validation loss is 1.453
#              10|             1%|          0m 0s|        0.01108|        0.00602|        1.45594
#              20|             2%|          0m 0s|        0.01262|        0.00766|        1.43411
#              30|             3%|          0m 0s|        0.01194|        0.00697|        1.41929
# ==> evaluating validation loss
# ==> validation loss is 1.380
#              40|             4%|          0m 0s|        0.01176|        0.00679|        1.40661
#              50|             5%|          0m 0s|        0.01234|        0.00730|        1.39445
#              60|             6%|          0m 0s|        0.01197|        0.00700|        1.38229
# ==> evaluating validation loss
# ==> validation loss is 1.351
#              70|             7%|          0m 1s|        0.01194|        0.00697|        1.36990
#              80|             8%|          0m 1s|        0.01180|        0.00687|        1.35723
#              90|             9%|          0m 1s|        0.01177|        0.00676|        1.34429
# ==> evaluating validation loss
# ==> validation loss is 1.322
#             100|            10%|          0m 1s|        0.01187|        0.00691|        1.33112
#             110|            11%|          0m 1s|        0.01215|        0.00709|        1.31776
#             120|            12%|          0m 1s|        0.01198|        0.00696|        1.30419
#             130|            13%|          0m 1s|        0.01209|        0.00708|        1.29035
# ==> evaluating validation loss
# ==> validation loss is 1.296
#             140|            14%|          0m 2s|        0.01195|        0.00697|        1.27620
#             150|            15%|          0m 2s|        0.01209|        0.00712|        1.26168
#             160|            16%|          0m 2s|        0.01201|        0.00706|        1.24678
# ==> evaluating validation loss
# ==> validation loss is 1.255
#             170|            17%|          0m 2s|        0.01210|        0.00716|        1.23151
#             180|            18%|          0m 2s|        0.01198|        0.00706|        1.21588
#             190|            19%|          0m 2s|        0.01192|        0.00701|        1.19990
# ==> evaluating validation loss
# ==> validation loss is 1.188
#             200|            20%|          0m 3s|        0.01183|        0.00693|        1.18357
#             210|            21%|          0m 3s|        0.01179|        0.00688|        1.16694
#             220|            22%|          0m 3s|        0.01175|        0.00685|        1.15002
#             230|            23%|          0m 3s|        0.01182|        0.00693|        1.13290
# ==> evaluating validation loss
# ==> validation loss is 1.094
#             240|            24%|          0m 3s|        0.01175|        0.00687|        1.11564
#             250|            25%|          0m 3s|        0.01181|        0.00694|        1.09837
#             260|            26%|          0m 3s|        0.01188|        0.00698|        1.08119
# ==> evaluating validation loss
# ==> validation loss is 1.024
#             270|            27%|          0m 4s|        0.01201|        0.00709|        1.06421
#             280|            28%|          0m 4s|        0.01197|        0.00705|        1.04748
#             290|            28%|          0m 4s|        0.01195|        0.00702|        1.03100
# ==> evaluating validation loss
# ==> validation loss is 0.977
#             300|            30%|          0m 4s|        0.01197|        0.00701|        1.01478
#             310|            31%|          0m 4s|        0.01236|        0.00725|        0.99878
#             320|            32%|          0m 5s|        0.01242|        0.00729|        0.98298
#             330|            33%|          0m 5s|        0.01258|        0.00743|        0.96734
# ==> evaluating validation loss
# ==> validation loss is 0.926
#             340|            34%|          0m 5s|        0.01256|        0.00740|        0.95184
#             350|            35%|          0m 5s|        0.01261|        0.00746|        0.93644
#             360|            36%|          0m 5s|        0.01259|        0.00743|        0.92112
# ==> evaluating validation loss
# ==> validation loss is 0.847
#             370|            37%|          0m 5s|        0.01253|        0.00738|        0.90587
#             380|            38%|          0m 6s|        0.01256|        0.00742|        0.89069
#             390|            39%|          0m 6s|        0.01250|        0.00738|        0.87558
# ==> evaluating validation loss
# ==> validation loss is 0.730
#             400|            40%|          0m 6s|        0.01266|        0.00745|        0.86056
#             410|            41%|          0m 6s|        0.01273|        0.00751|        0.84566
#             420|            42%|          0m 6s|        0.01277|        0.00750|        0.83091
# ==> evaluating validation loss
# ==> validation loss is 0.611
#             430|            43%|          0m 7s|        0.01292|        0.00763|        0.81636
#             440|            44%|          0m 7s|        0.01293|        0.00762|        0.80203
#             450|            45%|          0m 7s|        0.01299|        0.00766|        0.78795
#             460|            46%|          0m 7s|        0.01312|        0.00775|        0.77416
# ==> evaluating validation loss
# ==> validation loss is 0.509
#             470|            47%|          0m 7s|        0.01318|        0.00781|        0.76067
#             480|            48%|          0m 8s|        0.01332|        0.00792|        0.74750
#             490|            49%|          0m 8s|        0.01330|        0.00789|        0.73464
# ==> evaluating validation loss
# ==> validation loss is 0.434
#             500|            50%|          0m 8s|        0.01331|        0.00791|        0.72212
#             510|            51%|          0m 8s|        0.01326|        0.00788|        0.70993
#             520|            52%|          0m 8s|        0.01322|        0.00785|        0.69806
# ==> evaluating validation loss
# ==> validation loss is 0.377
#             530|            53%|          0m 8s|        0.01318|        0.00782|        0.68652
#             540|            54%|          0m 8s|        0.01314|        0.00779|        0.67530
#             550|            55%|          0m 9s|        0.01314|        0.00777|        0.66439
#             560|            56%|          0m 9s|        0.01324|        0.00786|        0.65379
# ==> evaluating validation loss
# ==> validation loss is 0.337
#             570|            56%|          0m 9s|        0.01324|        0.00786|        0.64349
#             580|            57%|          0m 9s|        0.01324|        0.00787|        0.63348
#             590|            59%|          0m 9s|        0.01320|        0.00784|        0.62376
# ==> evaluating validation loss
# ==> validation loss is 0.309
#             600|            60%|          0m 9s|        0.01320|        0.00785|        0.61431
#             610|            61%|         0m 10s|        0.01315|        0.00782|        0.60512
#             620|            62%|         0m 10s|        0.01311|        0.00779|        0.59619
# ==> evaluating validation loss
# ==> validation loss is 0.285
#             630|            63%|         0m 10s|        0.01308|        0.00776|        0.58751
#             640|            64%|         0m 10s|        0.01305|        0.00774|        0.57906
#             650|            65%|         0m 10s|        0.01302|        0.00772|        0.57085
#             660|            66%|         0m 10s|        0.01303|        0.00774|        0.56286
# ==> evaluating validation loss
# ==> validation loss is 0.267
#             670|            67%|         0m 10s|        0.01300|        0.00771|        0.55507
#             680|            68%|         0m 11s|        0.01301|        0.00773|        0.54750
#             690|            69%|         0m 11s|        0.01298|        0.00771|        0.54012
# ==> evaluating validation loss
# ==> validation loss is 0.252
#             700|            70%|         0m 11s|        0.01295|        0.00769|        0.53294
#             710|            71%|         0m 11s|        0.01300|        0.00772|        0.52594
#             720|            72%|         0m 11s|        0.01302|        0.00772|        0.51911
# ==> evaluating validation loss
# ==> validation loss is 0.241
#             730|            73%|         0m 12s|        0.01302|        0.00773|        0.51246
#             740|            74%|         0m 12s|        0.01300|        0.00771|        0.50597
#             750|            75%|         0m 12s|        0.01298|        0.00770|        0.49965
# ==> evaluating validation loss
# ==> validation loss is 0.229
#             760|            76%|         0m 12s|        0.01299|        0.00771|        0.49347
#             770|            77%|         0m 12s|        0.01296|        0.00770|        0.48745
#             780|            78%|         0m 12s|        0.01298|        0.00772|        0.48156
#             790|            79%|         0m 12s|        0.01295|        0.00769|        0.47582
# ==> evaluating validation loss
# ==> validation loss is 0.220
#             800|            80%|         0m 13s|        0.01292|        0.00767|        0.47021
#             810|            81%|         0m 13s|        0.01293|        0.00769|        0.46472
#             820|            82%|         0m 13s|        0.01290|        0.00766|        0.45937
# ==> evaluating validation loss
# ==> validation loss is 0.212
#             830|            83%|         0m 13s|        0.01291|        0.00768|        0.45413
#             840|            84%|         0m 13s|        0.01289|        0.00766|        0.44901
#             850|            85%|         0m 13s|        0.01286|        0.00764|        0.44401
# ==> evaluating validation loss
# ==> validation loss is 0.204
#             860|            86%|         0m 13s|        0.01284|        0.00762|        0.43911
#             870|            87%|         0m 14s|        0.01281|        0.00760|        0.43432
#             880|            88%|         0m 14s|        0.01279|        0.00758|        0.42963
#             890|            89%|         0m 14s|        0.01280|        0.00760|        0.42505
# ==> evaluating validation loss
# ==> validation loss is 0.198
#             900|            90%|         0m 14s|        0.01277|        0.00757|        0.42056
#             910|            91%|         0m 14s|        0.01278|        0.00759|        0.41616
#             920|            92%|         0m 14s|        0.01275|        0.00757|        0.41186
# ==> evaluating validation loss
# ==> validation loss is 0.194
#             930|            93%|         0m 14s|        0.01276|        0.00759|        0.40764
#             940|            94%|         0m 15s|        0.01275|        0.00757|        0.40351
#             950|            95%|         0m 15s|        0.01273|        0.00755|        0.39946
# ==> evaluating validation loss
# ==> validation loss is 0.190
#             960|            96%|         0m 15s|        0.01270|        0.00754|        0.39550
#             970|            97%|         0m 15s|        0.01268|        0.00752|        0.39161
#             980|            98%|         0m 15s|        0.01266|        0.00750|        0.38780
#             990|            99%|         0m 15s|        0.01267|        0.00752|        0.38406
# ==> evaluating validation loss
# ==> validation loss is 0.185
#            1000|           100%|         0m 15s|        0.01265|        0.00750|        0.38039
# ==> evaluating validation loss
# ==> validation loss is 0.184
# Independent(l=2)
#           #iter|       progress|     total_time|     batch_time|      data_time|       avg_loss
# ==> evaluating validation loss
# ==> validation loss is 1.463
#              10|             1%|          0m 0s|        0.01211|        0.00581|        1.46058
#              20|             2%|          0m 0s|        0.01335|        0.00728|        1.43797
#              30|             3%|          0m 0s|        0.01280|        0.00673|        1.42484
# ==> evaluating validation loss
# ==> validation loss is 1.379
#              40|             4%|          0m 0s|        0.01257|        0.00652|        1.41352
#              50|             5%|          0m 0s|        0.01296|        0.00694|        1.40216
#              60|             6%|          0m 0s|        0.01275|        0.00675|        1.39020
# ==> evaluating validation loss
# ==> validation loss is 1.347
#              70|             7%|          0m 1s|        0.01261|        0.00660|        1.37752
#              80|             8%|          0m 1s|        0.01252|        0.00649|        1.36373
#              90|             9%|          0m 1s|        0.01254|        0.00646|        1.34846
# ==> evaluating validation loss
# ==> validation loss is 1.275
#             100|            10%|          0m 1s|        0.01283|        0.00671|        1.33156
#             110|            11%|          0m 1s|        0.01293|        0.00673|        1.31291
#             120|            12%|          0m 1s|        0.01291|        0.00670|        1.29248
#             130|            13%|          0m 2s|        0.01311|        0.00689|        1.27041
# ==> evaluating validation loss
# ==> validation loss is 1.130
#             140|            14%|          0m 2s|        0.01305|        0.00682|        1.24702
#             150|            15%|          0m 2s|        0.01321|        0.00698|        1.22277
#             160|            16%|          0m 2s|        0.01314|        0.00691|        1.19793
# ==> evaluating validation loss
# ==> validation loss is 0.950
#             170|            17%|          0m 2s|        0.01345|        0.00715|        1.17277
#             180|            18%|          0m 2s|        0.01334|        0.00707|        1.14749
#             190|            19%|          0m 3s|        0.01328|        0.00702|        1.12230
# ==> evaluating validation loss
# ==> validation loss is 0.788
#             200|            20%|          0m 3s|        0.01328|        0.00699|        1.09730
#             210|            21%|          0m 3s|        0.01327|        0.00697|        1.07245
#             220|            22%|          0m 3s|        0.01324|        0.00695|        1.04762
#             230|            23%|          0m 3s|        0.01341|        0.00710|        1.02265
# ==> evaluating validation loss
# ==> validation loss is 0.632
#             240|            24%|          0m 4s|        0.01335|        0.00705|        0.99736
#             250|            25%|          0m 4s|        0.01342|        0.00712|        0.97169
#             260|            26%|          0m 4s|        0.01342|        0.00711|        0.94571
# ==> evaluating validation loss
# ==> validation loss is 0.430
#             270|            27%|          0m 4s|        0.01366|        0.00736|        0.91967
#             280|            28%|          0m 4s|        0.01374|        0.00738|        0.89387
#             290|            28%|          0m 4s|        0.01380|        0.00740|        0.86860
# ==> evaluating validation loss
# ==> validation loss is 0.281
#             300|            30%|          0m 5s|        0.01377|        0.00737|        0.84406
#             310|            31%|          0m 5s|        0.01378|        0.00735|        0.82037
#             320|            32%|          0m 5s|        0.01388|        0.00744|        0.79763
#             330|            33%|          0m 5s|        0.01390|        0.00748|        0.77587
# ==> evaluating validation loss
# ==> validation loss is 0.206
#             340|            34%|          0m 5s|        0.01383|        0.00742|        0.75511
#             350|            35%|          0m 6s|        0.01386|        0.00746|        0.73531
#             360|            36%|          0m 6s|        0.01382|        0.00742|        0.71645
# ==> evaluating validation loss
# ==> validation loss is 0.171
#             370|            37%|          0m 6s|        0.01377|        0.00738|        0.69848
#             380|            38%|          0m 6s|        0.01379|        0.00742|        0.68135
#             390|            39%|          0m 6s|        0.01374|        0.00737|        0.66502
# ==> evaluating validation loss
# ==> validation loss is 0.153
#             400|            40%|          0m 6s|        0.01369|        0.00734|        0.64943
#             410|            41%|          0m 7s|        0.01364|        0.00730|        0.63455
#             420|            42%|          0m 7s|        0.01360|        0.00726|        0.62032
# ==> evaluating validation loss
# ==> validation loss is 0.139
#             430|            43%|          0m 7s|        0.01362|        0.00729|        0.60670
#             440|            44%|          0m 7s|        0.01358|        0.00726|        0.59366
#             450|            45%|          0m 7s|        0.01370|        0.00737|        0.58117
#             460|            46%|          0m 7s|        0.01369|        0.00737|        0.56919
# ==> evaluating validation loss
# ==> validation loss is 0.131
#             470|            47%|          0m 8s|        0.01365|        0.00733|        0.55768
#             480|            48%|          0m 8s|        0.01375|        0.00743|        0.54664
#             490|            49%|          0m 8s|        0.01380|        0.00746|        0.53602
# ==> evaluating validation loss
# ==> validation loss is 0.124
#             500|            50%|          0m 8s|        0.01385|        0.00752|        0.52581
#             510|            51%|          0m 8s|        0.01387|        0.00752|        0.51598
#             520|            52%|          0m 8s|        0.01392|        0.00755|        0.50652
# ==> evaluating validation loss
# ==> validation loss is 0.118
#             530|            53%|          0m 9s|        0.01393|        0.00753|        0.49740
#             540|            54%|          0m 9s|        0.01393|        0.00752|        0.48861
#             550|            55%|          0m 9s|        0.01392|        0.00749|        0.48013
#             560|            56%|          0m 9s|        0.01395|        0.00753|        0.47194
# ==> evaluating validation loss
# ==> validation loss is 0.114
#             570|            56%|          0m 9s|        0.01391|        0.00750|        0.46403
#             580|            57%|         0m 10s|        0.01392|        0.00752|        0.45639
#             590|            59%|         0m 10s|        0.01389|        0.00749|        0.44900
# ==> evaluating validation loss
# ==> validation loss is 0.112
#             600|            60%|         0m 10s|        0.01399|        0.00758|        0.44184
#             610|            61%|         0m 10s|        0.01402|        0.00759|        0.43492
#             620|            62%|         0m 10s|        0.01402|        0.00758|        0.42821
# ==> evaluating validation loss
# ==> validation loss is 0.110
#             630|            63%|         0m 10s|        0.01399|        0.00756|        0.42171
#             640|            64%|         0m 11s|        0.01396|        0.00753|        0.41540
#             650|            65%|         0m 11s|        0.01393|        0.00751|        0.40928
#             660|            66%|         0m 11s|        0.01394|        0.00753|        0.40335
# ==> evaluating validation loss
# ==> validation loss is 0.107
#             670|            67%|         0m 11s|        0.01392|        0.00751|        0.39758
#             680|            68%|         0m 11s|        0.01394|        0.00754|        0.39198
#             690|            69%|         0m 11s|        0.01391|        0.00751|        0.38654
# ==> evaluating validation loss
# ==> validation loss is 0.105
#             700|            70%|         0m 12s|        0.01392|        0.00753|        0.38126
#             710|            71%|         0m 12s|        0.01389|        0.00751|        0.37611
#             720|            72%|         0m 12s|        0.01386|        0.00748|        0.37111
# ==> evaluating validation loss
# ==> validation loss is 0.104
#             730|            73%|         0m 12s|        0.01383|        0.00746|        0.36625
#             740|            74%|         0m 12s|        0.01380|        0.00744|        0.36153
#             750|            75%|         0m 12s|        0.01378|        0.00742|        0.35693
# ==> evaluating validation loss
# ==> validation loss is 0.106
#             760|            76%|         0m 13s|        0.01379|        0.00744|        0.35246
#             770|            77%|         0m 13s|        0.01376|        0.00742|        0.34810
#             780|            78%|         0m 13s|        0.01378|        0.00743|        0.34386
#             790|            79%|         0m 13s|        0.01375|        0.00741|        0.33974
# ==> evaluating validation loss
# ==> validation loss is 0.103
#             800|            80%|         0m 13s|        0.01372|        0.00739|        0.33570
#             810|            81%|         0m 13s|        0.01374|        0.00741|        0.33176
#             820|            82%|         0m 13s|        0.01373|        0.00740|        0.32791
# ==> evaluating validation loss
# ==> validation loss is 0.095
#             830|            83%|         0m 14s|        0.01371|        0.00738|        0.32415
#             840|            84%|         0m 14s|        0.01374|        0.00739|        0.32046
#             850|            85%|         0m 14s|        0.01378|        0.00737|        0.31685
# ==> evaluating validation loss
# ==> validation loss is 0.093
#             860|            86%|         0m 14s|        0.01386|        0.00742|        0.31333
#             870|            87%|         0m 14s|        0.01385|        0.00741|        0.30987
#             880|            88%|         0m 15s|        0.01387|        0.00742|        0.30650
#             890|            89%|         0m 15s|        0.01395|        0.00749|        0.30320
# ==> evaluating validation loss
# ==> validation loss is 0.092
#             900|            90%|         0m 15s|        0.01397|        0.00750|        0.29997
#             910|            91%|         0m 15s|        0.01401|        0.00754|        0.29681
#             920|            92%|         0m 15s|        0.01404|        0.00758|        0.29371
# ==> evaluating validation loss
# ==> validation loss is 0.092
#             930|            93%|         0m 16s|        0.01408|        0.00761|        0.29068
#             940|            94%|         0m 16s|        0.01410|        0.00760|        0.28771
#             950|            95%|         0m 16s|        0.01413|        0.00761|        0.28481
# ==> evaluating validation loss
# ==> validation loss is 0.090
#             960|            96%|         0m 16s|        0.01414|        0.00761|        0.28196
#             970|            97%|         0m 17s|        0.01414|        0.00761|        0.27917
#             980|            98%|         0m 17s|        0.01416|        0.00763|        0.27643
#             990|            99%|         0m 17s|        0.01418|        0.00766|        0.27375
# ==> evaluating validation loss
# ==> validation loss is 0.089
#            1000|           100%|         0m 17s|        0.01420|        0.00764|        0.27112
# ==> evaluating validation loss
# ==> validation loss is 0.088
# SharedBottom(l=1)
#           #iter|       progress|     total_time|     batch_time|      data_time|       avg_loss
# ==> evaluating validation loss
# ==> validation loss is 1.494
#              10|             1%|          0m 0s|        0.01183|        0.00632|        1.47499
#              20|             2%|          0m 0s|        0.01308|        0.00778|        1.44139
#              30|             3%|          0m 0s|        0.01236|        0.00714|        1.42193
# ==> evaluating validation loss
# ==> validation loss is 1.369
#              40|             4%|          0m 0s|        0.01198|        0.00691|        1.40544
#              50|             5%|          0m 0s|        0.01239|        0.00735|        1.38995
#              60|             6%|          0m 0s|        0.01217|        0.00718|        1.37446
# ==> evaluating validation loss
# ==> validation loss is 1.321
#              70|             7%|          0m 1s|        0.01196|        0.00699|        1.35907
#              80|             8%|          0m 1s|        0.01177|        0.00684|        1.34338
#              90|             9%|          0m 1s|        0.01164|        0.00672|        1.32672
# ==> evaluating validation loss
# ==> validation loss is 1.214
#             100|            10%|          0m 1s|        0.01187|        0.00694|        1.30856
#             110|            11%|          0m 1s|        0.01174|        0.00683|        1.28911
#             120|            12%|          0m 1s|        0.01187|        0.00699|        1.26895
#             130|            13%|          0m 1s|        0.01176|        0.00690|        1.24849
# ==> evaluating validation loss
# ==> validation loss is 1.088
#             140|            14%|          0m 2s|        0.01168|        0.00683|        1.22806
#             150|            15%|          0m 2s|        0.01178|        0.00695|        1.20789
#             160|            16%|          0m 2s|        0.01170|        0.00688|        1.18804
# ==> evaluating validation loss
# ==> validation loss is 1.000
#             170|            17%|          0m 2s|        0.01180|        0.00699|        1.16843
#             180|            18%|          0m 2s|        0.01174|        0.00693|        1.14894
#             190|            19%|          0m 2s|        0.01168|        0.00688|        1.12949
# ==> evaluating validation loss
# ==> validation loss is 0.901
#             200|            20%|          0m 2s|        0.01162|        0.00682|        1.10996
#             210|            21%|          0m 3s|        0.01156|        0.00677|        1.09019
#             220|            22%|          0m 3s|        0.01151|        0.00672|        1.07006
#             230|            23%|          0m 3s|        0.01159|        0.00681|        1.04955
# ==> evaluating validation loss
# ==> validation loss is 0.764
#             240|            24%|          0m 3s|        0.01154|        0.00677|        1.02871
#             250|            25%|          0m 3s|        0.01162|        0.00685|        1.00770
#             260|            26%|          0m 3s|        0.01158|        0.00681|        0.98670
# ==> evaluating validation loss
# ==> validation loss is 0.648
#             270|            27%|          0m 3s|        0.01164|        0.00688|        0.96586
#             280|            28%|          0m 4s|        0.01159|        0.00684|        0.94531
#             290|            28%|          0m 4s|        0.01156|        0.00680|        0.92513
# ==> evaluating validation loss
# ==> validation loss is 0.570
#             300|            30%|          0m 4s|        0.01153|        0.00677|        0.90538
#             310|            31%|          0m 4s|        0.01149|        0.00674|        0.88607
#             320|            32%|          0m 4s|        0.01146|        0.00671|        0.86720
#             330|            33%|          0m 4s|        0.01153|        0.00677|        0.84876
# ==> evaluating validation loss
# ==> validation loss is 0.504
#             340|            34%|          0m 4s|        0.01149|        0.00674|        0.83074
#             350|            35%|          0m 5s|        0.01155|        0.00680|        0.81313
#             360|            36%|          0m 5s|        0.01152|        0.00677|        0.79592
# ==> evaluating validation loss
# ==> validation loss is 0.434
#             370|            37%|          0m 5s|        0.01158|        0.00683|        0.77913
#             380|            38%|          0m 5s|        0.01154|        0.00680|        0.76278
#             390|            39%|          0m 5s|        0.01151|        0.00678|        0.74688
# ==> evaluating validation loss
# ==> validation loss is 0.370
#             400|            40%|          0m 5s|        0.01149|        0.00675|        0.73144
#             410|            41%|          0m 5s|        0.01146|        0.00673|        0.71648
#             420|            42%|          0m 6s|        0.01144|        0.00672|        0.70199
# ==> evaluating validation loss
# ==> validation loss is 0.322
#             430|            43%|          0m 6s|        0.01149|        0.00676|        0.68797
#             440|            44%|          0m 6s|        0.01147|        0.00674|        0.67442
#             450|            45%|          0m 6s|        0.01151|        0.00679|        0.66133
#             460|            46%|          0m 6s|        0.01149|        0.00677|        0.64868
# ==> evaluating validation loss
# ==> validation loss is 0.288
#             470|            47%|          0m 6s|        0.01147|        0.00676|        0.63646
#             480|            48%|          0m 6s|        0.01153|        0.00682|        0.62466
#             490|            49%|          0m 7s|        0.01151|        0.00680|        0.61326
# ==> evaluating validation loss
# ==> validation loss is 0.262
#             500|            50%|          0m 7s|        0.01149|        0.00678|        0.60225
#             510|            51%|          0m 7s|        0.01148|        0.00676|        0.59161
#             520|            52%|          0m 7s|        0.01146|        0.00674|        0.58132
# ==> evaluating validation loss
# ==> validation loss is 0.245
#             530|            53%|          0m 7s|        0.01149|        0.00678|        0.57137
#             540|            54%|          0m 7s|        0.01147|        0.00676|        0.56174
#             550|            55%|          0m 7s|        0.01146|        0.00675|        0.55243
#             560|            56%|          0m 7s|        0.01149|        0.00679|        0.54342
# ==> evaluating validation loss
# ==> validation loss is 0.232
#             570|            56%|          0m 8s|        0.01148|        0.00677|        0.53469
#             580|            57%|          0m 8s|        0.01152|        0.00681|        0.52623
#             590|            59%|          0m 8s|        0.01152|        0.00680|        0.51804
# ==> evaluating validation loss
# ==> validation loss is 0.220
#             600|            60%|          0m 8s|        0.01155|        0.00684|        0.51009
#             610|            61%|          0m 8s|        0.01154|        0.00683|        0.50238
#             620|            62%|          0m 8s|        0.01153|        0.00681|        0.49491
# ==> evaluating validation loss
# ==> validation loss is 0.212
#             630|            63%|          0m 9s|        0.01153|        0.00681|        0.48765
#             640|            64%|          0m 9s|        0.01151|        0.00679|        0.48060
#             650|            65%|          0m 9s|        0.01151|        0.00679|        0.47376
#             660|            66%|          0m 9s|        0.01156|        0.00683|        0.46710
# ==> evaluating validation loss
# ==> validation loss is 0.206
#             670|            67%|          0m 9s|        0.01157|        0.00684|        0.46064
#             680|            68%|          0m 9s|        0.01161|        0.00688|        0.45435
#             690|            69%|          0m 9s|        0.01160|        0.00687|        0.44823
# ==> evaluating validation loss
# ==> validation loss is 0.200
#             700|            70%|         0m 10s|        0.01163|        0.00689|        0.44228
#             710|            71%|         0m 10s|        0.01161|        0.00687|        0.43649
#             720|            72%|         0m 10s|        0.01159|        0.00686|        0.43084
# ==> evaluating validation loss
# ==> validation loss is 0.195
#             730|            73%|         0m 10s|        0.01158|        0.00685|        0.42535
#             740|            74%|         0m 10s|        0.01167|        0.00691|        0.41999
#             750|            75%|         0m 10s|        0.01166|        0.00690|        0.41478
# ==> evaluating validation loss
# ==> validation loss is 0.192
#             760|            76%|         0m 11s|        0.01170|        0.00693|        0.40969
#             770|            77%|         0m 11s|        0.01170|        0.00694|        0.40473
#             780|            78%|         0m 11s|        0.01179|        0.00701|        0.39989
#             790|            79%|         0m 11s|        0.01184|        0.00701|        0.39517
# ==> evaluating validation loss
# ==> validation loss is 0.190
#             800|            80%|         0m 11s|        0.01189|        0.00702|        0.39057
#             810|            81%|         0m 12s|        0.01194|        0.00706|        0.38606
#             820|            82%|         0m 12s|        0.01193|        0.00705|        0.38166
# ==> evaluating validation loss
# ==> validation loss is 0.184
#             830|            83%|         0m 12s|        0.01191|        0.00703|        0.37736
#             840|            84%|         0m 12s|        0.01190|        0.00702|        0.37316
#             850|            85%|         0m 12s|        0.01189|        0.00701|        0.36905
# ==> evaluating validation loss
# ==> validation loss is 0.182
#             860|            86%|         0m 12s|        0.01191|        0.00703|        0.36503
#             870|            87%|         0m 13s|        0.01190|        0.00702|        0.36110
#             880|            88%|         0m 13s|        0.01192|        0.00705|        0.35726
#             890|            89%|         0m 13s|        0.01190|        0.00703|        0.35350
# ==> evaluating validation loss
# ==> validation loss is 0.180
#             900|            90%|         0m 13s|        0.01189|        0.00702|        0.34982
#             910|            91%|         0m 13s|        0.01192|        0.00705|        0.34621
#             920|            92%|         0m 13s|        0.01190|        0.00703|        0.34268
# ==> evaluating validation loss
# ==> validation loss is 0.177
#             930|            93%|         0m 13s|        0.01192|        0.00706|        0.33922
#             940|            94%|         0m 14s|        0.01191|        0.00704|        0.33583
#             950|            95%|         0m 14s|        0.01190|        0.00703|        0.33251
# ==> evaluating validation loss
# ==> validation loss is 0.177
#             960|            96%|         0m 14s|        0.01188|        0.00702|        0.32926
#             970|            97%|         0m 14s|        0.01187|        0.00701|        0.32607
#             980|            98%|         0m 14s|        0.01185|        0.00700|        0.32295
#             990|            99%|         0m 14s|        0.01187|        0.00702|        0.31988
# ==> evaluating validation loss
# ==> validation loss is 0.174
#            1000|           100%|         0m 14s|        0.01186|        0.00701|        0.31688
# ==> evaluating validation loss
# ==> validation loss is 0.174
# SharedBottom(l=2)
#           #iter|       progress|     total_time|     batch_time|      data_time|       avg_loss
# ==> evaluating validation loss
# ==> validation loss is 1.466
#              10|             1%|          0m 0s|        0.01161|        0.00644|        1.45977
#              20|             2%|          0m 0s|        0.01559|        0.00922|        1.43467
#              30|             3%|          0m 0s|        0.01552|        0.00922|        1.42018
# ==> evaluating validation loss
# ==> validation loss is 1.370
#              40|             4%|          0m 0s|        0.01529|        0.00920|        1.40735
#              50|             5%|          0m 0s|        0.01446|        0.00856|        1.39458
#              60|             6%|          0m 1s|        0.01434|        0.00846|        1.38124
# ==> evaluating validation loss
# ==> validation loss is 1.333
#              70|             7%|          0m 1s|        0.01385|        0.00808|        1.36700
#              80|             8%|          0m 1s|        0.01351|        0.00782|        1.35164
#              90|             9%|          0m 1s|        0.01325|        0.00761|        1.33511
# ==> evaluating validation loss
# ==> validation loss is 1.241
#             100|            10%|          0m 1s|        0.01350|        0.00785|        1.31726
#             110|            11%|          0m 1s|        0.01329|        0.00770|        1.29793
#             120|            12%|          0m 1s|        0.01333|        0.00779|        1.27709
#             130|            13%|          0m 2s|        0.01316|        0.00765|        1.25492
# ==> evaluating validation loss
# ==> validation loss is 1.056
#             140|            14%|          0m 2s|        0.01297|        0.00750|        1.23177
#             150|            15%|          0m 2s|        0.01304|        0.00759|        1.20802
#             160|            16%|          0m 2s|        0.01292|        0.00750|        1.18403
# ==> evaluating validation loss
# ==> validation loss is 0.882
#             170|            17%|          0m 2s|        0.01282|        0.00741|        1.16015
#             180|            18%|          0m 2s|        0.01271|        0.00732|        1.13645
#             190|            19%|          0m 2s|        0.01261|        0.00724|        1.11275
# ==> evaluating validation loss
# ==> validation loss is 0.725
#             200|            20%|          0m 3s|        0.01268|        0.00733|        1.08868
#             210|            21%|          0m 3s|        0.01259|        0.00725|        1.06369
#             220|            22%|          0m 3s|        0.01252|        0.00720|        1.03765
#             230|            23%|          0m 3s|        0.01258|        0.00728|        1.01057
# ==> evaluating validation loss
# ==> validation loss is 0.507
#             240|            24%|          0m 3s|        0.01250|        0.00722|        0.98256
#             250|            25%|          0m 3s|        0.01255|        0.00727|        0.95390
#             260|            26%|          0m 3s|        0.01248|        0.00722|        0.92514
# ==> evaluating validation loss
# ==> validation loss is 0.307
#             270|            27%|          0m 4s|        0.01251|        0.00726|        0.89687
#             280|            28%|          0m 4s|        0.01245|        0.00721|        0.86951
#             290|            28%|          0m 4s|        0.01239|        0.00717|        0.84328
# ==> evaluating validation loss
# ==> validation loss is 0.215
#             300|            30%|          0m 4s|        0.01234|        0.00713|        0.81827
#             310|            31%|          0m 4s|        0.01229|        0.00708|        0.79450
#             320|            32%|          0m 4s|        0.01225|        0.00705|        0.77194
#             330|            33%|          0m 4s|        0.01230|        0.00711|        0.75053
# ==> evaluating validation loss
# ==> validation loss is 0.178
#             340|            34%|          0m 5s|        0.01226|        0.00707|        0.73021
#             350|            35%|          0m 5s|        0.01232|        0.00713|        0.71092
#             360|            36%|          0m 5s|        0.01227|        0.00710|        0.69260
# ==> evaluating validation loss
# ==> validation loss is 0.158
#             370|            37%|          0m 5s|        0.01230|        0.00714|        0.67518
#             380|            38%|          0m 5s|        0.01227|        0.00710|        0.65861
#             390|            39%|          0m 5s|        0.01223|        0.00707|        0.64282
# ==> evaluating validation loss
# ==> validation loss is 0.146
#             400|            40%|          0m 6s|        0.01219|        0.00704|        0.62777
#             410|            41%|          0m 6s|        0.01215|        0.00701|        0.61340
#             420|            42%|          0m 6s|        0.01219|        0.00702|        0.59968
# ==> evaluating validation loss
# ==> validation loss is 0.138
#             430|            43%|          0m 6s|        0.01222|        0.00706|        0.58657
#             440|            44%|          0m 6s|        0.01219|        0.00703|        0.57402
#             450|            45%|          0m 6s|        0.01222|        0.00707|        0.56201
#             460|            46%|          0m 6s|        0.01220|        0.00705|        0.55049
# ==> evaluating validation loss
# ==> validation loss is 0.130
#             470|            47%|          0m 7s|        0.01218|        0.00703|        0.53945
#             480|            48%|          0m 7s|        0.01228|        0.00712|        0.52886
#             490|            49%|          0m 7s|        0.01231|        0.00712|        0.51868
# ==> evaluating validation loss
# ==> validation loss is 0.127
#             500|            50%|          0m 7s|        0.01239|        0.00716|        0.50891
#             510|            51%|          0m 7s|        0.01241|        0.00716|        0.49951
#             520|            52%|          0m 8s|        0.01239|        0.00714|        0.49046
# ==> evaluating validation loss
# ==> validation loss is 0.121
#             530|            53%|          0m 8s|        0.01243|        0.00718|        0.48175
#             540|            54%|          0m 8s|        0.01239|        0.00715|        0.47335
#             550|            55%|          0m 8s|        0.01243|        0.00719|        0.46527
#             560|            56%|          0m 8s|        0.01240|        0.00717|        0.45747
# ==> evaluating validation loss
# ==> validation loss is 0.120
#             570|            56%|          0m 8s|        0.01238|        0.00715|        0.44992
#             580|            57%|          0m 8s|        0.01240|        0.00718|        0.44262
#             590|            59%|          0m 9s|        0.01237|        0.00715|        0.43557
# ==> evaluating validation loss
# ==> validation loss is 0.110
#             600|            60%|          0m 9s|        0.01238|        0.00717|        0.42875
#             610|            61%|          0m 9s|        0.01239|        0.00717|        0.42215
#             620|            62%|          0m 9s|        0.01241|        0.00719|        0.41579
# ==> evaluating validation loss
# ==> validation loss is 0.125
#             630|            63%|          0m 9s|        0.01240|        0.00717|        0.40966
#             640|            64%|          0m 9s|        0.01239|        0.00716|        0.40377
#             650|            65%|          0m 9s|        0.01238|        0.00715|        0.39811
#             660|            66%|         0m 10s|        0.01241|        0.00718|        0.39265
# ==> evaluating validation loss
# ==> validation loss is 0.130
#             670|            67%|         0m 10s|        0.01240|        0.00716|        0.38743
#             680|            68%|         0m 10s|        0.01242|        0.00719|        0.38239
#             690|            69%|         0m 10s|        0.01241|        0.00718|        0.37731
# ==> evaluating validation loss
# ==> validation loss is 0.106
#             700|            70%|         0m 10s|        0.01244|        0.00722|        0.37225
#             710|            71%|         0m 10s|        0.01242|        0.00720|        0.36731
#             720|            72%|         0m 11s|        0.01240|        0.00718|        0.36248
# ==> evaluating validation loss
# ==> validation loss is 0.101
#             730|            73%|         0m 11s|        0.01237|        0.00716|        0.35776
#             740|            74%|         0m 11s|        0.01236|        0.00715|        0.35317
#             750|            75%|         0m 11s|        0.01234|        0.00713|        0.34868
# ==> evaluating validation loss
# ==> validation loss is 0.096
#             760|            76%|         0m 11s|        0.01238|        0.00716|        0.34430
#             770|            77%|         0m 11s|        0.01237|        0.00716|        0.34004
#             780|            78%|         0m 11s|        0.01241|        0.00719|        0.33587
#             790|            79%|         0m 12s|        0.01241|        0.00719|        0.33181
# ==> evaluating validation loss
# ==> validation loss is 0.093
#             800|            80%|         0m 12s|        0.01244|        0.00723|        0.32785
#             810|            81%|         0m 12s|        0.01242|        0.00721|        0.32398
#             820|            82%|         0m 12s|        0.01244|        0.00722|        0.32020
# ==> evaluating validation loss
# ==> validation loss is 0.091
#             830|            83%|         0m 12s|        0.01244|        0.00721|        0.31651
#             840|            84%|         0m 12s|        0.01242|        0.00720|        0.31291
#             850|            85%|         0m 13s|        0.01240|        0.00719|        0.30938
# ==> evaluating validation loss
# ==> validation loss is 0.090
#             860|            86%|         0m 13s|        0.01243|        0.00721|        0.30594
#             870|            87%|         0m 13s|        0.01242|        0.00720|        0.30258
#             880|            88%|         0m 13s|        0.01244|        0.00722|        0.29929
#             890|            89%|         0m 13s|        0.01248|        0.00723|        0.29607
# ==> evaluating validation loss
# ==> validation loss is 0.089
#             900|            90%|         0m 13s|        0.01248|        0.00722|        0.29292
#             910|            91%|         0m 14s|        0.01253|        0.00726|        0.28983
#             920|            92%|         0m 14s|        0.01251|        0.00725|        0.28682
# ==> evaluating validation loss
# ==> validation loss is 0.087
#             930|            93%|         0m 14s|        0.01253|        0.00727|        0.28386
#             940|            94%|         0m 14s|        0.01251|        0.00726|        0.28097
#             950|            95%|         0m 14s|        0.01250|        0.00725|        0.27814
# ==> evaluating validation loss
# ==> validation loss is 0.086
#             960|            96%|         0m 14s|        0.01251|        0.00724|        0.27536
#             970|            97%|         0m 15s|        0.01252|        0.00723|        0.27265
#             980|            98%|         0m 15s|        0.01251|        0.00722|        0.26998
#             990|            99%|         0m 15s|        0.01252|        0.00723|        0.26737
# ==> evaluating validation loss
# ==> validation loss is 0.084
#            1000|           100%|         0m 15s|        0.01254|        0.00725|        0.26481
# ==> evaluating validation loss
# ==> validation loss is 0.084
# MMOE
#           #iter|       progress|     total_time|     batch_time|      data_time|       avg_loss
# ==> evaluating validation loss
# ==> validation loss is 1.518
#              10|             1%|          0m 0s|        0.01500|        0.00579|        1.51673
#              20|             2%|          0m 0s|        0.01668|        0.00745|        1.49062
#              30|             3%|          0m 0s|        0.01720|        0.00740|        1.47029
# ==> evaluating validation loss
# ==> validation loss is 1.399
#              40|             4%|          0m 0s|        0.01746|        0.00780|        1.45418
#              50|             5%|          0m 1s|        0.01710|        0.00754|        1.44106
#              60|             6%|          0m 1s|        0.01683|        0.00741|        1.42989
# ==> evaluating validation loss
# ==> validation loss is 1.374
#              70|             7%|          0m 1s|        0.01693|        0.00734|        1.41981
#              80|             8%|          0m 1s|        0.01726|        0.00745|        1.41020
#              90|             9%|          0m 2s|        0.01743|        0.00748|        1.40056
# ==> evaluating validation loss
# ==> validation loss is 1.356
#             100|            10%|          0m 2s|        0.01817|        0.00788|        1.39048
#             110|            11%|          0m 2s|        0.01818|        0.00780|        1.37975
#             120|            12%|          0m 2s|        0.01855|        0.00815|        1.36828
#             130|            13%|          0m 3s|        0.01857|        0.00810|        1.35609
# ==> evaluating validation loss
# ==> validation loss is 1.334
#             140|            14%|          0m 3s|        0.01837|        0.00797|        1.34321
#             150|            15%|          0m 3s|        0.01857|        0.00814|        1.32966
#             160|            16%|          0m 3s|        0.01855|        0.00809|        1.31548
# ==> evaluating validation loss
# ==> validation loss is 1.299
#             170|            17%|          0m 4s|        0.01852|        0.00803|        1.30077
#             180|            18%|          0m 4s|        0.01838|        0.00793|        1.28564
#             190|            19%|          0m 4s|        0.01831|        0.00786|        1.27024
# ==> evaluating validation loss
# ==> validation loss is 1.262
#             200|            20%|          0m 4s|        0.01831|        0.00793|        1.25472
#             210|            21%|          0m 4s|        0.01814|        0.00783|        1.23920
#             220|            22%|          0m 4s|        0.01816|        0.00790|        1.22380
#             230|            23%|          0m 5s|        0.01804|        0.00783|        1.20857
# ==> evaluating validation loss
# ==> validation loss is 1.237
#             240|            24%|          0m 5s|        0.01790|        0.00775|        1.19356
#             250|            25%|          0m 5s|        0.01791|        0.00780|        1.17880
#             260|            26%|          0m 5s|        0.01780|        0.00774|        1.16430
# ==> evaluating validation loss
# ==> validation loss is 1.227
#             270|            27%|          0m 6s|        0.01780|        0.00777|        1.15008
#             280|            28%|          0m 6s|        0.01769|        0.00770|        1.13611
#             290|            28%|          0m 6s|        0.01759|        0.00764|        1.12241
# ==> evaluating validation loss
# ==> validation loss is 1.230
#             300|            30%|          0m 6s|        0.01756|        0.00760|        1.10896
#             310|            31%|          0m 6s|        0.01771|        0.00764|        1.09574
#             320|            32%|          0m 7s|        0.01766|        0.00762|        1.08277
#             330|            33%|          0m 7s|        0.01774|        0.00772|        1.07001
# ==> evaluating validation loss
# ==> validation loss is 1.237
#             340|            34%|          0m 7s|        0.01766|        0.00767|        1.05748
#             350|            35%|          0m 7s|        0.01770|        0.00771|        1.04515
#             360|            36%|          0m 7s|        0.01765|        0.00766|        1.03303
# ==> evaluating validation loss
# ==> validation loss is 1.245
#             370|            37%|          0m 8s|        0.01766|        0.00769|        1.02111
#             380|            38%|          0m 8s|        0.01759|        0.00765|        1.00939
#             390|            39%|          0m 8s|        0.01753|        0.00762|        0.99785
# ==> evaluating validation loss
# ==> validation loss is 1.254
#             400|            40%|          0m 8s|        0.01750|        0.00758|        0.98649
#             410|            41%|          0m 8s|        0.01756|        0.00757|        0.97531
#             420|            42%|          0m 9s|        0.01762|        0.00758|        0.96431
# ==> evaluating validation loss
# ==> validation loss is 1.262
#             430|            43%|          0m 9s|        0.01773|        0.00767|        0.95348
#             440|            44%|          0m 9s|        0.01766|        0.00764|        0.94281
#             450|            45%|          0m 9s|        0.01766|        0.00766|        0.93230
#             460|            46%|          0m 9s|        0.01766|        0.00765|        0.92194
# ==> evaluating validation loss
# ==> validation loss is 1.265
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
#             470|            47%|         0m 10s|        0.01768|        0.00769|        0.91173
#             480|            48%|         0m 10s|        0.01764|        0.00766|        0.90189
#             490|            49%|         0m 10s|        0.01760|        0.00763|        0.89243
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             500|            50%|         0m 10s|        0.01756|        0.00761|        0.88331
#             510|            51%|         0m 10s|        0.01752|        0.00758|        0.87453
#             520|            52%|         0m 11s|        0.01749|        0.00756|        0.86606
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             530|            53%|         0m 11s|        0.01750|        0.00759|        0.85788
#             540|            54%|         0m 11s|        0.01745|        0.00756|        0.84998
#             550|            55%|         0m 11s|        0.01745|        0.00758|        0.84235
#             560|            56%|         0m 11s|        0.01741|        0.00755|        0.83496
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             570|            56%|         0m 12s|        0.01736|        0.00752|        0.82781
#             580|            57%|         0m 12s|        0.01737|        0.00755|        0.82089
#             590|            59%|         0m 12s|        0.01732|        0.00752|        0.81418
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             600|            60%|         0m 12s|        0.01733|        0.00754|        0.80767
#             610|            61%|         0m 12s|        0.01729|        0.00752|        0.80136
#             620|            62%|         0m 13s|        0.01726|        0.00749|        0.79523
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             630|            63%|         0m 13s|        0.01727|        0.00752|        0.78927
#             640|            64%|         0m 13s|        0.01725|        0.00750|        0.78349
#             650|            65%|         0m 13s|        0.01721|        0.00748|        0.77786
#             660|            66%|         0m 13s|        0.01724|        0.00752|        0.77238
# ==> evaluating validation loss
# ==> validation loss is 1.265
# Epoch    20: reducing learning rate of group 0 to 1.0000e-05.
#             670|            67%|         0m 14s|        0.01725|        0.00752|        0.76705
#             680|            68%|         0m 14s|        0.01732|        0.00757|        0.76188
#             690|            69%|         0m 14s|        0.01740|        0.00758|        0.75685
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             700|            70%|         0m 15s|        0.01754|        0.00767|        0.75197
#             710|            71%|         0m 15s|        0.01762|        0.00770|        0.74722
#             720|            72%|         0m 15s|        0.01761|        0.00769|        0.74260
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             730|            73%|         0m 15s|        0.01763|        0.00769|        0.73811
#             740|            74%|         0m 16s|        0.01767|        0.00769|        0.73374
#             750|            75%|         0m 16s|        0.01767|        0.00768|        0.72948
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             760|            76%|         0m 16s|        0.01778|        0.00775|        0.72533
#             770|            77%|         0m 16s|        0.01780|        0.00776|        0.72129
#             780|            78%|         0m 16s|        0.01780|        0.00778|        0.71735
#             790|            79%|         0m 17s|        0.01777|        0.00776|        0.71351
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             800|            80%|         0m 17s|        0.01781|        0.00779|        0.70976
#             810|            81%|         0m 17s|        0.01780|        0.00778|        0.70611
#             820|            82%|         0m 17s|        0.01778|        0.00776|        0.70254
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             830|            83%|         0m 18s|        0.01774|        0.00774|        0.69906
#             840|            84%|         0m 18s|        0.01772|        0.00773|        0.69566
#             850|            85%|         0m 18s|        0.01771|        0.00772|        0.69233
# ==> evaluating validation loss
# ==> validation loss is 1.265
# Epoch    26: reducing learning rate of group 0 to 1.0000e-06.
#             860|            86%|         0m 18s|        0.01771|        0.00774|        0.68909
#             870|            87%|         0m 18s|        0.01768|        0.00772|        0.68591
#             880|            88%|         0m 19s|        0.01768|        0.00773|        0.68281
#             890|            89%|         0m 19s|        0.01766|        0.00771|        0.67978
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             900|            90%|         0m 19s|        0.01762|        0.00769|        0.67682
#             910|            91%|         0m 19s|        0.01764|        0.00771|        0.67392
#             920|            92%|         0m 19s|        0.01761|        0.00769|        0.67108
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             930|            93%|         0m 20s|        0.01758|        0.00767|        0.66830
#             940|            94%|         0m 20s|        0.01755|        0.00766|        0.66559
#             950|            95%|         0m 20s|        0.01752|        0.00764|        0.66293
# ==> evaluating validation loss
# ==> validation loss is 1.265
#             960|            96%|         0m 20s|        0.01753|        0.00766|        0.66032
#             970|            97%|         0m 20s|        0.01750|        0.00764|        0.65777
#             980|            98%|         0m 21s|        0.01751|        0.00765|        0.65527
#             990|            99%|         0m 21s|        0.01748|        0.00763|        0.65283
# ==> evaluating validation loss
# ==> validation loss is 1.265
#            1000|           100%|         0m 21s|        0.01745|        0.00762|        0.65043
# ==> evaluating validation loss
# ==> validation loss is 1.265

# %%
for t in trainers:
    net_name = t.net.name()
    #plt.plot(t.train_losses, label=net_name)
    plt.plot(t.val_losses, label=net_name)
    
plt.legend()
plt.ylabel('loss', fontsize=15)
plt.xlabel('iterations', fontsize=15)
plt.title('cos(w1,w2)={} n={}'.format(cos_sim, n))
plt.savefig('figures/p={},n={}.png'.format(cos_sim,n))
plt.show()

# %% [markdown]
# ## load trained model

# %%
def loadTrainer(loadname):
    t = TrainFeedForward(eval(loadname.split('/')[-1].split('.')[0]), 
                         DataLoader(CosDataset(1)))
    t.load_checkpoint(loadname)
    return t

t = loadTrainer('models2/1/c=0.5/Independent(l=1).pth.tar')
plt.plot(t.val_losses)
plt.show()
# Out:
# per layer neuron: 68
# => loading checkpoint 'models2/1/c=0.5/Independent(l=1).pth.tar'
# => loaded checkpoint 'models2/1/c=0.5/Independent(l=1).pth.tar' (iteration 1001)

# %%
import glob

for fn in glob.glob('models2/1/c=0.5/*'):
    if 'best' not in fn:
        print(fn)
        t = loadTrainer(fn)
        plt.plot(t.val_losses, label=t.net.name())
        
plt.legend()
plt.show()
# Out:
# models2/1/c=0.5/Independent(l=1).pth.tar
# per layer neuron: 68
# => loading checkpoint 'models2/1/c=0.5/Independent(l=1).pth.tar'
# => loaded checkpoint 'models2/1/c=0.5/Independent(l=1).pth.tar' (iteration 1001)
# models2/1/c=0.5/Independent(l=2).pth.tar
# per layer neuron: 47
# => loading checkpoint 'models2/1/c=0.5/Independent(l=2).pth.tar'
# => loaded checkpoint 'models2/1/c=0.5/Independent(l=2).pth.tar' (iteration 1001)
# models2/1/c=0.5/SharedBottom(l=1).pth.tar
# per layer neuron: 126
# => loading checkpoint 'models2/1/c=0.5/SharedBottom(l=1).pth.tar'
# => loaded checkpoint 'models2/1/c=0.5/SharedBottom(l=1).pth.tar' (iteration 1001)
# models2/1/c=0.5/SharedBottom(l=2).pth.tar
# per layer neuron: 76
# => loading checkpoint 'models2/1/c=0.5/SharedBottom(l=2).pth.tar'
# => loaded checkpoint 'models2/1/c=0.5/SharedBottom(l=2).pth.tar' (iteration 1001)
